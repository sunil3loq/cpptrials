# %%
from pandas import *
pandas.__version__
# Out:
# '0.12.0'

# %%
names = read_csv('./baby-names2.csv')

# %%
names.head()
# Out:
#    year     name      prop  sex soundex
# 0  1880     John  0.081541  boy    J500
# 1  1880  William  0.080511  boy    W450
# 2  1880    James  0.050057  boy    J520
# 3  1880  Charles  0.045167  boy    C642
# 4  1880   George  0.043292  boy    G620

# %%
names[names.year==1881]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 1000 to 130999
# Data columns (total 5 columns):
# year       2000  non-null values
# name       2000  non-null values
# prop       2000  non-null values
# sex        2000  non-null values
# soundex    2000  non-null values
# dtypes: float64(1), int64(1), object(3)

# %%
boys = names[names.sex=='boy']
girls = names[names.sex=='girl']

# %%
boys
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129000 entries, 0 to 128999
# Data columns (total 5 columns):
# year       129000  non-null values
# name       129000  non-null values
# prop       129000  non-null values
# sex        129000  non-null values
# soundex    129000  non-null values
# dtypes: float64(1), int64(1), object(3)

# %%
girls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129000 entries, 129000 to 257999
# Data columns (total 5 columns):
# year       129000  non-null values
# name       129000  non-null values
# prop       129000  non-null values
# sex        129000  non-null values
# soundex    129000  non-null values
# dtypes: float64(1), int64(1), object(3)

# %%
help(boys.groupby('year'))
# Out:
# Help on DataFrameGroupBy in module pandas.core.groupby object:
#
# class DataFrameGroupBy(NDFrameGroupBy)
#  |  Method resolution order:
#  |      DataFrameGroupBy
#  |      NDFrameGroupBy
#  |      GroupBy
#  |      pandas.core.base.PandasObject
#  |      pandas.core.base.StringMixin
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __getitem__(self, key)
#  |
#  |  boxplot = boxplot_frame_groupby(grouped, subplots=True, column=None, fontsize=None, rot=0, grid=True, figsize=None, **kwds)
#  |      Make box plots from DataFrameGroupBy data.
#  |
#  |      Parameters
#  |      ----------
#  |      grouped : Grouped DataFrame
#  |      subplots :
#  |          * ``False`` - no subplots will be used
#  |          * ``True`` - create a subplot for each group
#  |      column : column name or list of names, or vector
#  |          Can be any valid input to groupby
#  |      fontsize : int or string
#  |      rot : label rotation angle
# ...

# %%
names.groupby(['year','sex']).size()
# Out:
# year  sex
# 1880  boy     1000
#       girl    1000
# 1881  boy     1000
#       girl    1000
# 1882  boy     1000
#       girl    1000
# 1883  boy     1000
#       girl    1000
# 1884  boy     1000
#       girl    1000
# 1885  boy     1000
#       girl    1000
# 1886  boy     1000
#       girl    1000
# 1887  boy     1000
#       girl    1000
# 1888  boy     1000
#       girl    1000
# 1889  boy     1000
#       girl    1000
# 1890  boy     1000
#       girl    1000
# 1891  boy     1000
#       girl    1000
# 1892  boy     1000
#       girl    1000
# 1893  boy     1000
#       girl    1000
# 1894  boy     1000
#       girl    1000
# 1895  boy     1000
#       girl    1000
# 1896  boy     1000
#       girl    1000
# 1897  boy     1000
#       girl    1000
# 1898  boy     1000
#       girl    1000
# 1899  boy     1000
#       girl    1000
# 1900  boy     1000
#       girl    1000
# 1901  boy     1000
#       girl    1000
# 1902  boy     1000
#       girl    1000
# 1903  boy     1000
# ...

# %%
#selecting the outer level of the heirarchical index
names.groupby(['year','sex']).size().ix[2000]
# Out:
# sex
# boy     1000
# girl    1000
# dtype: int64

# %%
#getting the most popula boy name in 2000
boys.ix[boys[boys.year==2000].prop.idxmax()]
# Out:
# year           2000
# name          Jacob
# prop       0.016514
# sex             boy
# soundex        J210
# Name: 120000, dtype: object

# %%
def get_max_record(group):
        return group.ix[group.prop.idxmax()]
# Out:
# year           1880
# name           Mary
# prop       0.072381
# sex            girl
# soundex        M600
# Name: 129000, dtype: object

# %%
get_max_record(boys)
# Out:
# year           1880
# name           John
# prop       0.081541
# sex             boy
# soundex        J500
# Name: 0, dtype: object

# %%
get_max_record(girls)
# Out:
# year           1880
# name           Mary
# prop       0.072381
# sex            girl
# soundex        M600
# Name: 129000, dtype: object

# %%
get_max_record(names)
# Out:
# year           1880
# name           John
# prop       0.081541
# sex             boy
# soundex        J500
# Name: 0, dtype: object

# %%
boys.groupby('year')

# %%
boys.groupby('year').apply(get_max_record)
# Out:
#       year     name      prop  sex soundex
# year
# 1880  1880     John  0.081541  boy    J500
# 1881  1881     John  0.080975  boy    J500
# 1882  1882     John  0.078314  boy    J500
# 1883  1883     John  0.079066  boy    J500
# 1884  1884     John  0.076476  boy    J500
# 1885  1885     John  0.075517  boy    J500
# 1886  1886     John  0.075820  boy    J500
# 1887  1887     John  0.074181  boy    J500
# 1888  1888     John  0.071186  boy    J500
# 1889  1889     John  0.071804  boy    J500
# 1890  1890     John  0.071034  boy    J500
# 1891  1891     John  0.070292  boy    J500
# 1892  1892     John  0.068759  boy    J500
# 1893  1893     John  0.066495  boy    J500
# 1894  1894     John  0.065961  boy    J500
# 1895  1895     John  0.065699  boy    J500
# 1896  1896     John  0.063051  boy    J500
# 1897  1897     John  0.061907  boy    J500
# 1898  1898     John  0.061770  boy    J500
# 1899  1899     John  0.060674  boy    J500
# 1900  1900     John  0.060619  boy    J500
# ...

# %%
help(apply)
# Out:
# Help on built-in function apply in module __builtin__:
#
# apply(...)
#     apply(object[, args[, kwargs]]) -> value
#
#     Call a callable object with positional arguments taken from the tuple args,
#     and keyword arguments taken from the optional dictionary kwargs.
#     Note that classes are callable, as are instances with a __call__() method.
#
#     Deprecated since release 2.3. Instead, use the extended call syntax:
#         function(*args, **keywords).

# %%
result = boys.groupby('year').apply(get_max_record)

# %%
#how popularity changes with year of most popular name
result.prop.plot()

# %%
idf = boys.set_index(['name','year'])

# %%
idf[-10:]
# Out:
#                    prop  sex soundex
# name     year
# Baron    2008  0.000090  boy    B650
# Carlo    2008  0.000090  boy    C640
# Carsen   2008  0.000090  boy    C625
# Fletcher 2008  0.000090  boy    F432
# Izayah   2008  0.000090  boy    I200
# Kolten   2008  0.000090  boy    K435
# Damari   2008  0.000089  boy    D560
# Hugh     2008  0.000089  boy    H200
# Jensen   2008  0.000089  boy    J525
# Yurem    2008  0.000089  boy    Y650

# %%
trav = idf.ix['Travis']

# %%
trav.prop.plot()

# %%
idf
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 129000 entries, (John, 1880) to (Yurem, 2008)
# Data columns (total 3 columns):
# prop       129000  non-null values
# sex        129000  non-null values
# soundex    129000  non-null values
# dtypes: float64(1), object(2)

# %%
idf.ix['John',1880]
# Out:
# prop       0.081541
# sex             boy
# soundex        J500
# Name: (John, 1880), dtype: object

# %%
type(idf.ix['John',1880])
# Out:
# pandas.core.series.Series

# %%
boys.groupby('name')['prop'].mean().order()
# Out:
# name
# Danniel     0.000027
# Kennard     0.000027
# Deryl       0.000028
# Grayling    0.000028
# Michial     0.000028
# Cheryl      0.000028
# Dwyane      0.000028
# Levern      0.000029
# Diane       0.000029
# Randolf     0.000029
# Theodis     0.000029
# Kimball     0.000029
# Renard      0.000029
# Patric      0.000029
# Lex         0.000030
# ...
# Paul       0.008322
# Daniel     0.008517
# Frank      0.010386
# Edward     0.011069
# Richard    0.014183
# Thomas     0.014739
# George     0.016254
# David      0.016737
# Joseph     0.017771
# Michael    0.018342
# Charles    0.019521
# Robert     0.029625
# William    0.034182
# James      0.035465
# John       0.041082
# Name: prop, Length: 3437, dtype: float64

# %%
boys.groupby('name')['prop'].describe()
# Out:
# name
# Aaden  count    1.000000
#        mean     0.000442
#        std           NaN
#        min      0.000442
#        25%      0.000442
#        50%      0.000442
#        75%      0.000442
#        max      0.000442
# Aarav  count    1.000000
#        mean     0.000101
#        std           NaN
#        min      0.000101
#        25%      0.000101
#        50%      0.000101
#        75%      0.000101
# ...
# Zion    mean     0.000490
#         std      0.000165
#         min      0.000119
#         25%      0.000419
#         50%      0.000482
#         75%      0.000558
#         max      0.000731
# Zollie  count    8.000000
#         mean     0.000060
#         std      0.000012
#         min      0.000049
#         25%      0.000054
#         50%      0.000055
#         75%      0.000061
#         max      0.000087
# Length: 27496, dtype: float64

# %%
boys['prop'].describe()
# Out:
# count    129000.000000
# mean          0.000916
# std           0.003441
# min           0.000026
# 25%           0.000071
# 50%           0.000142
# 75%           0.000453
# max           0.081541
# dtype: float64

# %%
boys.describe()
# Out:
#                 year           prop
# count  129000.000000  129000.000000
# mean     1944.000000       0.000916
# std        37.238118       0.003441
# min      1880.000000       0.000026
# 25%      1912.000000       0.000071
# 50%      1944.000000       0.000142
# 75%      1976.000000       0.000453
# max      2008.000000       0.081541

# %%
type(boys.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
boys.groupby('year')['prop'].describe()
# Out:
# year
# 1880  count    1000.000000
#       mean        0.000931
#       std         0.004871
#       min         0.000042
#       25%         0.000059
#       50%         0.000118
#       75%         0.000372
#       max         0.081541
# 1881  count    1000.000000
#       mean        0.000930
#       std         0.004812
#       min         0.000037
#       25%         0.000065
#       50%         0.000120
#       75%         0.000369
# ...
# 2007  mean        0.000801
#       std         0.001498
#       min         0.000087
#       25%         0.000134
#       50%         0.000238
#       75%         0.000634
#       max         0.010948
# 2008  count    1000.000000
#       mean        0.000795
#       std         0.001455
#       min         0.000089
#       25%         0.000138
#       50%         0.000250
#       75%         0.000642
#       max         0.010355
# Length: 1032, dtype: float64

# %%
df = boys[boys.year==2008].sort_index(by='prop',ascending=False)
df.prop
# Out:
# 128000    0.010355
# 128001    0.009437
# 128002    0.009301
# 128003    0.008799
# 128004    0.008702
# 128005    0.008566
# 128006    0.008442
# 128007    0.008438
# 128008    0.008268
# 128009    0.008061
# 128010    0.007877
# 128011    0.007694
# 128012    0.007570
# 128013    0.007467
# 128014    0.007262
# ...
# 128985    0.000092
# 128986    0.000091
# 128987    0.000091
# 128988    0.000091
# 128989    0.000091
# 128992    0.000090
# 128994    0.000090
# 128993    0.000090
# 128995    0.000090
# 128991    0.000090
# 128990    0.000090
# 128997    0.000089
# 128998    0.000089
# 128996    0.000089
# 128999    0.000089
# Name: prop, Length: 1000, dtype: float64

# %%
df.prop.cumsum().searchsorted(0.5)
# Out:
# 127

# %%
def get_quantile_count(group,qcount=0.5):
    df = group.sort_index(by='prop',ascending=False)
    return df.prop.cumsum().searchsorted(qcount)

boys.groupby('year').apply(get_quantile_count).plot()
